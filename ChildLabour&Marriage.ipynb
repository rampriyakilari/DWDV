# %%
# !pip install pandas

# %%
import pandas as pd
cl= pd.read_csv('National Child Labour.csv')
cl
# Out:
#                                            Series Name  \
# 0    Children in employment, total (% of children a...
# 1    Children in employment, total (% of children a...
# 2    Children in employment, total (% of children a...
# 3    Children in employment, total (% of children a...
# 4    Children in employment, total (% of children a...
# ..                                                 ...
# 269   Data from database: World Development Indicators
# 270                           Last Updated: 09/19/2023
# 271                                               Code
# 272                                     SL.TLF.0714.ZS
# 273  Country surveys define the ages for child labo...
#
#                                            Series Code  \
# 0                                       SL.TLF.0714.ZS
# 1                                       SL.TLF.0714.ZS
# 2                                       SL.TLF.0714.ZS
# 3                                       SL.TLF.0714.ZS
# ...

# %%
cl.shape
# Out:
# (274, 16)

# %%
cl.isnull().sum()
# Out:
# Series Name      3
# Series Code      5
# Country Name     5
# Country Code     5
# 1990 [YR1990]    6
# 2000 [YR2000]    6
# 2013 [YR2013]    6
# 2014 [YR2014]    6
# 2015 [YR2015]    6
# 2016 [YR2016]    6
# 2017 [YR2017]    7
# 2018 [YR2018]    8
# 2019 [YR2019]    8
# 2020 [YR2020]    8
# 2021 [YR2021]    8
# 2022 [YR2022]    8
# dtype: int64

# %%
cm= pd.read_csv('Child Marriage.csv')
cm
# Out:
#                            Country Name Female Married by 15  \
# 0                           Afghanistan                    4
# 1                               Albania                   1@
# 2                               Algeria                    0
# 3                               Andorra                  NaN
# 4                                Angola                    8
# ..                                  ...                  ...
# 197  Venezuela (Bolivarian Republic of)                  NaN
# 198                            Viet Nam                    1
# 199                               Yemen                    9
# 200                              Zambia                    5
# 201                            Zimbabwe                    5
#
#      Female Married by 18  Reference year   Data source Male Married by 18  \
# 0                    28.0          2017.0  ALCS 2016-17                  7
# 1                    12.0          2018.0   DHS 2017-18                  1
# ...

# %%
cm.isnull().sum()
# Out:
# Country Name              0
# Female Married by 15     74
# Female Married by 18     74
# Reference year           74
# Data source              74
# Male Married by 18      107
# Male Reference year     107
# Data source.1           107
# dtype: int64

# %%
cm.shape
# Out:
# (202, 8)

# %%
#Check duplicates and missing data
cl.duplicated().sum()
# Out:
# 2

# %%
#to display duplicated rows
cl.loc[cl.duplicated()]
# Out:
#     Series Name Series Code Country Name Country Code 1990 [YR1990]  \
# 267         NaN         NaN          NaN          NaN           NaN
# 268         NaN         NaN          NaN          NaN           NaN
#
#     2000 [YR2000] 2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016]  \
# 267           NaN           NaN           NaN           NaN           NaN
# 268           NaN           NaN           NaN           NaN           NaN
#
#     2017 [YR2017] 2018 [YR2018] 2019 [YR2019] 2020 [YR2020] 2021 [YR2021]  \
# 267           NaN           NaN           NaN           NaN           NaN
# 268           NaN           NaN           NaN           NaN           NaN
#
#     2022 [YR2022]
# 267           NaN
# 268           NaN

# %%
#to drop duplicates rows
cl = cl.drop_duplicates()

# %%
cl.shape
# Out:
# (266, 16)

# %%
cl['Series Code'].dropna()
# Out:
# 0      SL.TLF.0714.ZS
# 1      SL.TLF.0714.ZS
# 2      SL.TLF.0714.ZS
# 3      SL.TLF.0714.ZS
# 4      SL.TLF.0714.ZS
#             ...
# 261    SL.TLF.0714.ZS
# 262    SL.TLF.0714.ZS
# 263    SL.TLF.0714.ZS
# 264    SL.TLF.0714.ZS
# 265    SL.TLF.0714.ZS
# Name: Series Code, Length: 266, dtype: object

# %%
cl.shape
# Out:
# (266, 16)

# %%
cl.head(20)
# Out:
#                                           Series Name     Series Code  \
# 0   Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 1   Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 2   Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 3   Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 4   Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 5   Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 6   Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 7   Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 8   Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 9   Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 10  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 11  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# ...

# %%
#to find null values
cl.isnull().sum()
# Out:
# Series Name      0
# Series Code      0
# Country Name     0
# Country Code     0
# 1990 [YR1990]    0
# 2000 [YR2000]    0
# 2013 [YR2013]    0
# 2014 [YR2014]    0
# 2015 [YR2015]    0
# 2016 [YR2016]    0
# 2017 [YR2017]    0
# 2018 [YR2018]    0
# 2019 [YR2019]    0
# 2020 [YR2020]    0
# 2021 [YR2021]    0
# 2022 [YR2022]    0
# dtype: int64

# %%
cl.isnull().sum().sum()
# Out:
# 0

# %%
#to display null values
cl.isna().any()
# Out:
# Series Name      False
# Series Code      False
# Country Name     False
# Country Code     False
# 1990 [YR1990]    False
# 2000 [YR2000]    False
# 2013 [YR2013]    False
# 2014 [YR2014]    False
# 2015 [YR2015]    False
# 2016 [YR2016]    False
# 2017 [YR2017]    False
# 2018 [YR2018]    False
# 2019 [YR2019]    False
# 2020 [YR2020]    False
# 2021 [YR2021]    False
# 2022 [YR2022]    False
# dtype: bool

# %%
cl[cl['Country Name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Series Name, Series Code, Country Name, Country Code, 1990 [YR1990], 2000 [YR2000], 2013 [YR2013], 2014 [YR2014], 2015 [YR2015], 2016 [YR2016], 2017 [YR2017], 2018 [YR2018], 2019 [YR2019], 2020 [YR2020], 2021 [YR2021], 2022 [YR2022]]
# Index: []

# %%
cl
# Out:
#                                            Series Name  \
# 0    Children in employment, total (% of children a...
# 1    Children in employment, total (% of children a...
# 2    Children in employment, total (% of children a...
# 3    Children in employment, total (% of children a...
# 4    Children in employment, total (% of children a...
# ..                                                 ...
# 269   Data from database: World Development Indicators
# 270                           Last Updated: 09/19/2023
# 271                                               Code
# 272                                     SL.TLF.0714.ZS
# 273  Country surveys define the ages for child labo...
#
#                                            Series Code  \
# 0                                       SL.TLF.0714.ZS
# 1                                       SL.TLF.0714.ZS
# 2                                       SL.TLF.0714.ZS
# 3                                       SL.TLF.0714.ZS
# ...

# %%
cm
# Out:
#                            Country Name Female Married by 15  \
# 0                           Afghanistan                    4
# 1                               Albania                   1@
# 2                               Algeria                    0
# 3                               Andorra                  NaN
# 4                                Angola                    8
# ..                                  ...                  ...
# 197  Venezuela (Bolivarian Republic of)                  NaN
# 198                            Viet Nam                    1
# 199                               Yemen                    9
# 200                              Zambia                    5
# 201                            Zimbabwe                    5
#
#      Female Married by 18  Reference year   Data source Male Married by 18  \
# 0                    28.0          2017.0  ALCS 2016-17                  7
# 1                    12.0          2018.0   DHS 2017-18                  1
# ...

# %%
#To rename column values
cl=cl.rename(columns={'Country Name':'Country'})

# %%
cl.head()
# Out:
#                                          Series Name     Series Code  \
# 0  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 1  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 2  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 3  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 4  Children in employment, total (% of children a...  SL.TLF.0714.ZS
#
#           Country Country Code 1990 [YR1990] 2000 [YR2000]     2013 [YR2013]  \
# 0     Afghanistan          AFG            ..            ..                ..
# 1         Albania          ALB            ..      36.58605                ..
# 2         Algeria          DZA            ..            ..  7.50076369799783
# 3  American Samoa          ASM            ..            ..                ..
# 4         Andorra          AND            ..            ..                ..
#
#   2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018]  \
# ...

# %%
#To fill the missing values
cl['Series Code']=cl['Series Code'].fillna(value=0)

# %%
cl
# Out:
#                                            Series Name     Series Code  \
# 0    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 1    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 2    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 3    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 4    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# ..                                                 ...             ...
# 261  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 262  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 263  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 264  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 265  Children in employment, total (% of children a...  SL.TLF.0714.ZS
#
#                                         Country Country Code 1990 [YR1990]  \
# ...

# %%
cl1=cl.fillna(method='bfill')
# Out:
# C:\Users\STUDENT\AppData\Local\Temp\ipykernel_11796\680848506.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   cl1=cl.fillna(method='bfill')

# %%
cl1
# Out:
#                                            Series Name     Series Code  \
# 0    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 1    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 2    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 3    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 4    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# ..                                                 ...             ...
# 261  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 262  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 263  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 264  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 265  Children in employment, total (% of children a...  SL.TLF.0714.ZS
#
#                                         Country Country Code 1990 [YR1990]  \
# ...

# %%
#(B)to eliminate missmatch
cc=cl[cl['Country Code']=='AND']

# %%
cc
# Out:
#                                          Series Name     Series Code  Country  \
# 4  Children in employment, total (% of children a...  SL.TLF.0714.ZS  Andorra
#
#   Country Code 1990 [YR1990] 2000 [YR2000] 2013 [YR2013] 2014 [YR2014]  \
# 4          AND            ..            ..            ..            ..
#
#   2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019]  \
# 4            ..            ..            ..            ..            ..
#
#   2020 [YR2020] 2021 [YR2021] 2022 [YR2022]
# 4            ..            ..            ..

# %%
cc2=cl[cl['Country Code']!='AND']

# %%
cc2
# Out:
#                                            Series Name     Series Code  \
# 0    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 1    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 2    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 3    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 5    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# ..                                                 ...             ...
# 261  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 262  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 263  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 264  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 265  Children in employment, total (% of children a...  SL.TLF.0714.ZS
#
#                                         Country Country Code 1990 [YR1990]  \
# ...

# %%
#to merge, join, concat functions on 2 datasets
new=pd.concat([cl1,cm],axis=1)

# %%
new
# Out:
#                                            Series Name     Series Code  \
# 0    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 1    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 2    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 3    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 4    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# ..                                                 ...             ...
# 261  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 262  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 263  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 264  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 265  Children in employment, total (% of children a...  SL.TLF.0714.ZS
#
#                                         Country Country Code 1990 [YR1990]  \
# ...

# %%
new2=new.merge(cl,indicator=True,how='outer')

# %%
new2
# Out:
#                                            Series Name     Series Code  \
# 0    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 1    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 2    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 3    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 4    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# ..                                                 ...             ...
# 261  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 262  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 263  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 264  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 265  Children in employment, total (% of children a...  SL.TLF.0714.ZS
#
#                                         Country Country Code 1990 [YR1990]  \
# ...

# %%
#to remove line breaks columnswise
cl['Country'] = cl['Country'].str.replace('\n', ' ')

# %%
cl.head()
# Out:
#                                          Series Name     Series Code  \
# 0  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 1  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 2  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 3  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 4  Children in employment, total (% of children a...  SL.TLF.0714.ZS
#
#           Country Country Code 1990 [YR1990] 2000 [YR2000]     2013 [YR2013]  \
# 0     Afghanistan          AFG            ..            ..                ..
# 1         Albania          ALB            ..      36.58605                ..
# 2         Algeria          DZA            ..            ..  7.50076369799783
# 3  American Samoa          ASM            ..            ..                ..
# 4         Andorra          AND            ..            ..                ..
#
#   2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018]  \
# ...

# %%
#to remove line breaks row-wise
cl.replace('\n','',regex=True)
# Out:
#                                            Series Name     Series Code  \
# 0    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 1    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 2    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 3    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 4    Children in employment, total (% of children a...  SL.TLF.0714.ZS
# ..                                                 ...             ...
# 261  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 262  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 263  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 264  Children in employment, total (% of children a...  SL.TLF.0714.ZS
# 265  Children in employment, total (% of children a...  SL.TLF.0714.ZS
#
#                                         Country Country Code 1990 [YR1990]  \
# ...

# %%
cm.head(20)
# Out:
#            Country Name Female Married by 15  Female Married by 18  \
# 0           Afghanistan                    4                  28.0
# 1               Albania                   1@                  12.0
# 2               Algeria                    0                   3.0
# 3               Andorra                  NaN                   NaN
# 4                Angola                    8                  30.0
# 5              Anguilla                  NaN                   NaN
# 6   Antigua and Barbuda                  NaN                   NaN
# 7             Argentina                  NaN                   NaN
# 8               Armenia                    0                   5.0
# 9             Australia                  NaN                   NaN
# 10              Austria                  NaN                   NaN
# 11           Azerbaijan                    2                  11.0
# 12              Bahamas                  NaN                   NaN
# ...

# %%
#to display whitespaces
cm['Data source']=cm['Data source'].str.strip()

# %%
cm.head(10)
# Out:
#           Country Name Female Married by 15  Female Married by 18  \
# 0          Afghanistan                    4                  28.0
# 1              Albania                   1@                  12.0
# 2              Algeria                    0                   3.0
# 3              Andorra                  NaN                   NaN
# 4               Angola                    8                  30.0
# 5             Anguilla                  NaN                   NaN
# 6  Antigua and Barbuda                  NaN                   NaN
# 7            Argentina                  NaN                   NaN
# 8              Armenia                    0                   5.0
# 9            Australia                  NaN                   NaN
#
#    Reference year   Data source Male Married by 18  Male Reference year  \
# 0          2017.0  ALCS 2016-17                  7               2015.0
# 1          2018.0   DHS 2017-18                  1               2018.0
# ...

# %%
#to remove special characters from columns
cm['Female Married by 15'] = cm['Female Married by 15'].str.replace(r'\W', '', regex=True)

# %%
cm.head(20)
# Out:
#            Country Name Female Married by 15  Female Married by 18  \
# 0           Afghanistan                    4                  28.0
# 1               Albania                    1                  12.0
# 2               Algeria                    0                   3.0
# 3               Andorra                  NaN                   NaN
# 4                Angola                    8                  30.0
# 5              Anguilla                  NaN                   NaN
# 6   Antigua and Barbuda                  NaN                   NaN
# 7             Argentina                  NaN                   NaN
# 8               Armenia                    0                   5.0
# 9             Australia                  NaN                   NaN
# 10              Austria                  NaN                   NaN
# 11           Azerbaijan                    2                  11.0
# 12              Bahamas                  NaN                   NaN
# ...

# %%
#to remove special characters from whole data
cm = cm.replace(r'\W', '', regex=True)

# %%
cm.head(20)
# Out:
#          Country Name Female Married by 15  Female Married by 18  \
# 0         Afghanistan                    4                  28.0
# 1             Albania                    1                  12.0
# 2             Algeria                    0                   3.0
# 3             Andorra                  NaN                   NaN
# 4              Angola                    8                  30.0
# 5            Anguilla                  NaN                   NaN
# 6   AntiguaandBarbuda                  NaN                   NaN
# 7           Argentina                  NaN                   NaN
# 8             Armenia                    0                   5.0
# 9           Australia                  NaN                   NaN
# 10            Austria                  NaN                   NaN
# 11         Azerbaijan                    2                  11.0
# 12            Bahamas                  NaN                   NaN
# ...
