# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
#Discovery
import pandas as pd
df=pd.read_csv('Customer.csv')
df.head()
# Out:
#   Customer ID    Customer Name    Segment  Age        Country  \
# 0    CG-12520      Claire Gute   Consumer   67  United States
# 1    DV-13045  Darrin Van Huff  Corporate   31  United States
# 2    SO-20335   Sean O'Donnell   Consumer   65  United States
# 3    BH-11710  Brosina Hoffman   Consumer   20  United States
# 4    AA-10480     Andrew Allen   Consumer   50  United States
#
#               City           State  Postal Code Region
# 0        Henderson        Kentucky        42420  South
# 1      Los Angeles      California        90036   West
# 2  Fort Lauderdale         Florida        33311  South
# 3      Los Angeles      California        90032   West
# 4          Concord  North Carolina        28027  South

# %%
#Structuring
df.shape
# Out:
# (793, 9)

# %%
df.dtypes
# Out:
# Customer ID      object
# Customer Name    object
# Segment          object
# Age               int64
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Customer ID', 'Customer Name', 'Segment', 'Age', 'Country', 'City',
#        'State', 'Postal Code', 'Region'],
#       dtype='object')

# %%
df.head(10)
# Out:
#   Customer ID       Customer Name      Segment  Age        Country  \
# 0    CG-12520         Claire Gute     Consumer   67  United States
# 1    DV-13045     Darrin Van Huff    Corporate   31  United States
# 2    SO-20335      Sean O'Donnell     Consumer   65  United States
# 3    BH-11710     Brosina Hoffman     Consumer   20  United States
# 4    AA-10480        Andrew Allen     Consumer   50  United States
# 5    IM-15070        Irene Maddox     Consumer   66  United States
# 6    HP-14815       Harold Pawlan  Home Office   20  United States
# 7    PK-19075           Pete Kriz     Consumer   46  United States
# 8    AG-10270     Alejandro Grove     Consumer   18  United States
# 9    ZD-21925  Zuschuss Donatelli     Consumer   66  United States
#
#               City           State  Postal Code   Region
# 0        Henderson        Kentucky        42420    South
# 1      Los Angeles      California        90036     West
# 2  Fort Lauderdale         Florida        33311    South
# 3      Los Angeles      California        90032     West
# 4          Concord  North Carolina        28027    South
# 5          Seattle      Washington        98103     West
# 6       Fort Worth           Texas        76106  Central
# 7          Madison       Wisconsin        53711  Central
# 8      West Jordan            Utah        84084     West
# 9    San Francisco      California        94109     West

# %%
df.tail(20)
# Out:
#     Customer ID      Customer Name      Segment  Age        Country  \
# 773    EM-14200      Evan Minnotte  Home Office   52  United States
# 774    AO-10810  Anthony O'Donnell    Corporate   66  United States
# 775    MH-17440      Mark Haberlin    Corporate   47  United States
# 776    SS-20515    Shirley Schmidt  Home Office   31  United States
# 777    LD-16855       Lela Donovan    Corporate   52  United States
# 778    VP-21760   Victoria Pisteka    Corporate   35  United States
# 779    TC-21145      Theresa Coyne    Corporate   63  United States
# 780    IM-15055      Ionia McGrath     Consumer   40  United States
# 781    AR-10570     Anemone Ratner     Consumer   36  United States
# 782    CM-12715     Craig Molinari    Corporate   53  United States
# 783    FW-14395     Fred Wasserman    Corporate   41  United States
# 784    LC-16960    Lindsay Castell  Home Office   57  United States
# 785    HE-14800       Harold Engle    Corporate   31  United States
# 786    BD-11560     Brendan Dodson  Home Office   54  United States
# 787    HD-14785      Harold Dahlen  Home Office   32  United States
# 788    CJ-11875       Carl Jackson    Corporate   64  United States
# 789    RS-19870         Roy Skaria  Home Office   39  United States
# 790    SC-20845         Sung Chung     Consumer   69  United States
# 791    RE-19405    Ricardo Emerson     Consumer   35  United States
# 792    SM-20905  Susan MacKendrick     Consumer   46  United States
#
#                   City         State  Postal Code   Region
# 773     Virginia Beach      Virginia        23464    South
# 774        Los Angeles    California        90045     West
# 775      New York City      New York        10035     East
# 776         Louisville      Kentucky        40214    South
# 777            Chicago      Illinois        60653  Central
# 778      San Francisco    California        94109     West
# 779           Lakewood    New Jersey         8701     East
# 780          Roseville    California        95661     West
# 781           Columbus       Georgia        31907    South
# 782         Huntsville         Texas        77340  Central
# 783         Huntsville       Alabama        35810    South
# 784          Arlington      Virginia        22204    South
# 785            Chicago      Illinois        60623  Central
# 786             Fresno    California        93727     West
# 787       Philadelphia  Pennsylvania        19143     East
# 788       Philadelphia  Pennsylvania        19140     East
# 789         Burlington          Iowa        52601  Central
# 790  Arlington Heights      Illinois        60004  Central
# 791               Kent          Ohio        44240     East
# 792             Newark          Ohio        43055     East

# %%
#Standardization
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 793 entries, 0 to 792
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer ID    793 non-null    object
#  1   Customer Name  793 non-null    object
#  2   Segment        793 non-null    object
#  3   Age            793 non-null    int64
#  4   Country        793 non-null    object
#  5   City           793 non-null    object
#  6   State          793 non-null    object
#  7   Postal Code    793 non-null    int64
#  8   Region         793 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 55.9+ KB

# %%
df.describe()
# Out:
#               Age   Postal Code
# count  793.000000    793.000000
# mean    44.467844  55229.717528
# std     15.526673  31679.223816
# min     18.000000   1841.000000
# 25%     31.000000  27217.000000
# 50%     45.000000  55901.000000
# 75%     58.000000  90004.000000
# max     70.000000  99207.000000

# %%
#Normalization
df['City']=df['City'].str.lower()

# %%
df.head()
# Out:
#   Customer ID    Customer Name    Segment  Age        Country  \
# 0    CG-12520      Claire Gute   Consumer   67  United States
# 1    DV-13045  Darrin Van Huff  Corporate   31  United States
# 2    SO-20335   Sean O'Donnell   Consumer   65  United States
# 3    BH-11710  Brosina Hoffman   Consumer   20  United States
# 4    AA-10480     Andrew Allen   Consumer   50  United States
#
#               City           State  Postal Code Region
# 0        henderson        Kentucky        42420  South
# 1      los angeles      California        90036   West
# 2  fort lauderdale         Florida        33311  South
# 3      los angeles      California        90032   West
# 4          concord  North Carolina        28027  South

# %%
df['State']=df['State'].str.replace('Iowa','Ohio')

# %%
df.tail()
# Out:
#     Customer ID      Customer Name      Segment  Age        Country  \
# 788    CJ-11875       Carl Jackson    Corporate   64  United States
# 789    RS-19870         Roy Skaria  Home Office   39  United States
# 790    SC-20845         Sung Chung     Consumer   69  United States
# 791    RE-19405    Ricardo Emerson     Consumer   35  United States
# 792    SM-20905  Susan MacKendrick     Consumer   46  United States
#
#                   City         State  Postal Code   Region
# 788       philadelphia  Pennsylvania        19140     East
# 789         burlington          Ohio        52601  Central
# 790  arlington heights      Illinois        60004  Central
# 791               kent          Ohio        44240     East
# 792             newark          Ohio        43055     East

# %%
#Data Cleaning
#find null values
df.isnull()
# Out:
#      Customer ID  Customer Name  Segment    Age  Country   City  State  \
# 0          False          False    False  False    False  False  False
# 1          False          False    False  False    False  False  False
# 2          False          False    False  False    False  False  False
# 3          False          False    False  False    False  False  False
# 4          False          False    False  False    False  False  False
# ..           ...            ...      ...    ...      ...    ...    ...
# 788        False          False    False  False    False  False  False
# 789        False          False    False  False    False  False  False
# 790        False          False    False  False    False  False  False
# 791        False          False    False  False    False  False  False
# 792        False          False    False  False    False  False  False
#
#      Postal Code  Region
# 0          False   False
# 1          False   False
# 2          False   False
# 3          False   False
# 4          False   False
# ..           ...     ...
# 788        False   False
# 789        False   False
# 790        False   False
# 791        False   False
# 792        False   False
#
# [793 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Customer ID      0
# Customer Name    0
# Segment          0
# Age              0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isnull().any()
# Out:
# Customer ID      False
# Customer Name    False
# Age              False
# Country          False
# City             False
# State            False
# Postal Code      False
# Region           False
# dtype: bool

# %%
#find duplicates
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 788    False
# 789    False
# 790    False
# 791    False
# 792    False
# Length: 793, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#delete duplicates
df.drop_duplicates()
# Out:
#     Customer ID      Customer Name      Segment  Age        Country  \
# 0      CG-12520        Claire Gute     Consumer   67  United States
# 1      DV-13045    Darrin Van Huff    Corporate   31  United States
# 2      SO-20335     Sean O'Donnell     Consumer   65  United States
# 3      BH-11710    Brosina Hoffman     Consumer   20  United States
# 4      AA-10480       Andrew Allen     Consumer   50  United States
# ..          ...                ...          ...  ...            ...
# 788    CJ-11875       Carl Jackson    Corporate   64  United States
# 789    RS-19870         Roy Skaria  Home Office   39  United States
# 790    SC-20845         Sung Chung     Consumer   69  United States
# 791    RE-19405    Ricardo Emerson     Consumer   35  United States
# 792    SM-20905  Susan MacKendrick     Consumer   46  United States
#
#                   City           State  Postal Code   Region
# 0            henderson        Kentucky        42420    South
# 1          los angeles      California        90036     West
# 2      fort lauderdale         Florida        33311    South
# 3          los angeles      California        90032     West
# 4              concord  North Carolina        28027    South
# ..                 ...             ...          ...      ...
# 788       philadelphia    Pennsylvania        19140     East
# 789         burlington            Ohio        52601  Central
# 790  arlington heights        Illinois        60004  Central
# 791               kent            Ohio        44240     East
# 792             newark            Ohio        43055     East
#
# [793 rows x 9 columns]

# %%
#drop rows with missing data
df.dropna()
# Out:
#     Customer ID      Customer Name      Segment  Age        Country  \
# 0      CG-12520        Claire Gute     Consumer   67  United States
# 1      DV-13045    Darrin Van Huff    Corporate   31  United States
# 2      SO-20335     Sean O'Donnell     Consumer   65  United States
# 3      BH-11710    Brosina Hoffman     Consumer   20  United States
# 4      AA-10480       Andrew Allen     Consumer   50  United States
# ..          ...                ...          ...  ...            ...
# 788    CJ-11875       Carl Jackson    Corporate   64  United States
# 789    RS-19870         Roy Skaria  Home Office   39  United States
# 790    SC-20845         Sung Chung     Consumer   69  United States
# 791    RE-19405    Ricardo Emerson     Consumer   35  United States
# 792    SM-20905  Susan MacKendrick     Consumer   46  United States
#
#                   City           State  Postal Code   Region
# 0            henderson        Kentucky        42420    South
# 1          los angeles      California        90036     West
# 2      fort lauderdale         Florida        33311    South
# 3          los angeles      California        90032     West
# 4              concord  North Carolina        28027    South
# ..                 ...             ...          ...      ...
# 788       philadelphia    Pennsylvania        19140     East
# 789         burlington            Ohio        52601  Central
# 790  arlington heights        Illinois        60004  Central
# 791               kent            Ohio        44240     East
# 792             newark            Ohio        43055     East
#
# [793 rows x 9 columns]

# %%
#Delete a column
df.drop(['Segment'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Customer ID    Customer Name  Age        Country             City  \
# 0    CG-12520      Claire Gute   67  United States        Henderson
# 1    DV-13045  Darrin Van Huff   31  United States      Los Angeles
# 2    SO-20335   Sean O'Donnell   65  United States  Fort Lauderdale
# 3    BH-11710  Brosina Hoffman   20  United States      Los Angeles
# 4    AA-10480     Andrew Allen   50  United States          Concord
#
#             State  Postal Code Region
# 0        Kentucky        42420  South
# 1      California        90036   West
# 2         Florida        33311  South
# 3      California        90032   West
# 4  North Carolina        28027  South

# %%
#delete a row
df.drop(790,axis=0,inplace=True)

# %%
df.tail()
# Out:
#     Customer ID      Customer Name  Age        Country          City  \
# 787    HD-14785      Harold Dahlen   32  United States  Philadelphia
# 788    CJ-11875       Carl Jackson   64  United States  Philadelphia
# 789    RS-19870         Roy Skaria   39  United States    Burlington
# 791    RE-19405    Ricardo Emerson   35  United States          Kent
# 792    SM-20905  Susan MacKendrick   46  United States        Newark
#
#             State  Postal Code   Region
# 787  Pennsylvania        19143     East
# 788  Pennsylvania        19140     East
# 789          Iowa        52601  Central
# 791          Ohio        44240     East
# 792          Ohio        43055     East

# %%
#delete a column if any NAN values in specific columns
df.dropna(subset=['Age'])
# Out:
#     Customer ID      Customer Name  Age        Country             City  \
# 0      CG-12520        Claire Gute   67  United States        Henderson
# 1      DV-13045    Darrin Van Huff   31  United States      Los Angeles
# 2      SO-20335     Sean O'Donnell   65  United States  Fort Lauderdale
# 3      BH-11710    Brosina Hoffman   20  United States      Los Angeles
# 4      AA-10480       Andrew Allen   50  United States          Concord
# ..          ...                ...  ...            ...              ...
# 787    HD-14785      Harold Dahlen   32  United States     Philadelphia
# 788    CJ-11875       Carl Jackson   64  United States     Philadelphia
# 789    RS-19870         Roy Skaria   39  United States       Burlington
# 791    RE-19405    Ricardo Emerson   35  United States             Kent
# 792    SM-20905  Susan MacKendrick   46  United States           Newark
#
#               State  Postal Code   Region
# 0          Kentucky        42420    South
# 1        California        90036     West
# 2           Florida        33311    South
# 3        California        90032     West
# 4    North Carolina        28027    South
# ..              ...          ...      ...
# 787    Pennsylvania        19143     East
# 788    Pennsylvania        19140     East
# 789            Iowa        52601  Central
# 791            Ohio        44240     East
# 792            Ohio        43055     East
#
# [792 rows x 8 columns]

# %%
df.duplicated(subset=['Age'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 787     True
# 788     True
# 789     True
# 791     True
# 792     True
# Length: 792, dtype: bool

# %%
df=df.drop_duplicates(subset=['Age'])

# %%
df.shape
# Out:
# (53, 8)

# %%
df.head()
# Out:
#   Customer ID    Customer Name  Age        Country             City  \
# 0    CG-12520      Claire Gute   67  United States        Henderson
# 1    DV-13045  Darrin Van Huff   31  United States      Los Angeles
# 2    SO-20335   Sean O'Donnell   65  United States  Fort Lauderdale
# 3    BH-11710  Brosina Hoffman   20  United States      Los Angeles
# 4    AA-10480     Andrew Allen   50  United States          Concord
#
#             State  Postal Code Region
# 0        Kentucky        42420  South
# 1      California        90036   West
# 2         Florida        33311  South
# 3      California        90032   West
# 4  North Carolina        28027  South

# %%
#find outliers
df[df['Age']<20]
# Out:
#    Customer ID    Customer Name  Age        Country         City  State  \
# 8     AG-10270  Alejandro Grove   18  United States  West Jordan   Utah
# 15    MA-17560     Matt Abelman   19  United States      Houston  Texas
#
#     Postal Code   Region
# 8         84084     West
# 15        77095  Central

# %%
df=df.drop(df[df['Age'] > 20].index)

# %%
df.head(10)
# Out:
#    Customer ID    Customer Name  Age        Country         City       State  \
# 3     BH-11710  Brosina Hoffman   20  United States  Los Angeles  California
# 8     AG-10270  Alejandro Grove   18  United States  West Jordan        Utah
# 15    MA-17560     Matt Abelman   19  United States      Houston       Texas
#
#     Postal Code   Region
# 3         90032     West
# 8         84084     West
# 15        77095  Central
